# %% [markdown]
# ![outliers_ma.png](data:image/png;base64,...)

# %% [markdown]
# ## Importante
# Cada vez que desarrolles un ejercicio registra tu tiempo de resolución, a este se le designa **TR** y está asociado a un **RTE** (**R**ango de **T**iempo **E**sperado), en caso que tú tiempo este sobre el máximo **RTE** no te desanimes `el dasafío es primero resolver, luego mejorar tus tiempos.`

# %% [markdown]
# ---
# ## Cuadernillo M6 - Evaluando con  if_elif_else(1-1) RTE [10 -  15]min

# %% [markdown]
# ##### Evaluemos multiples opciones.
# |**if `condición_1`:**||
# |:--|:--:|
# ||Bloque_1 (si se cumple condición_1, se ejecutan las instrucciones del bloque identado dentro del if)|
# |**elif `condición_2`:**||
# ||Bloque_2 (condición_1 fue **False**, por lo que se evalua si se cumple condición_2 se ejecutan las intrucciones del Bloque_2|
# |**else:** (sino)||
# ||Bloque_3 (no se cumple ninguna de las condiciones anteriores por lo que se ejecutan las instrucciones del Bloque_3)|
#
# * Podemos tener tantos **elif** como reglas de negocio dadas.

# %%
# Bien, manos a la obra inicia tu cuadernillo registrando hora inicio, sólo en comentario.

# %% [markdown]
# #### M5.1 Elabore un programa que aplique un descuento o recargo a la venta dependiento del medio de pago.
# 1. El usuario debe ingresar
#     - Total de venta en un número entero, que representa valor en dolares
#     - Medio de pago.
# 2. Reglas de negocio:
# - Medios de pago: TC (Tarjeta de crédito) - TE(Transferecnica Electrónica)- EF (Efectivo)
# - Para TC aplica un recargo de 5% sobre la venta.
# - Para TE no aplica ni recargo, ni descuento.
# - Para EF aplica un 20%
# 3. Mostrar por pantalla el descuento y/o recargo aplicado en dólares y el total a pagar en dolares.
# 4. En caso de no tener descuento mostrar un mensaje indicando que no aplica descuento.
#
# **Ejemplo de resultado**
#
# Ingreso de datos:
# - Venta: 1000
# - Medio de pago: EF
#
# Mensaje:
# - Descuento aplicado: 200 USD
# - Total a pagar: 800 USD
#
# * Recuerda validar qu el ingreso de datos sean números positivos

# %%
#Desarrollo solución M6.1

# %%
#¡¡¡Felicitaciones!!!, terminaste tu cuadernillo.
# Por favor registra hora Final y tu tiempo de ejecucción, sólo en comentario.
